# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

pd.set_option('display.max_columns',(90))
pd.set_option('display.max_rows',(16))

# %%
df=pd.read_csv('~/Box/TCPL_Database/Step_5_tcpl_processed/AKP_Giacomini_Txptr_pct_inh_phase123.csv')
df
# Out:
#        spid  chid      casn           chnm dsstox_substance_id      code  \
# 0        10    10      3779  isoproterenol       DTXSID6025486     C3779
# 1        10    10      3779  isoproterenol       DTXSID6025486     C3779
# 2        10    10      3779  isoproterenol       DTXSID6025486     C3779
# 3        10    10      3779  isoproterenol       DTXSID6025486     C3779
# 4        10    10      3779  isoproterenol       DTXSID6025486     C3779
# ...     ...   ...       ...            ...                 ...       ...
# 11678    99    97  000097_1       000097_1            NOTOX_97  C0000971
# 11679    99    97  000097_1       000097_1            NOTOX_97  C0000971
# 11680    99    97  000097_1       000097_1            NOTOX_97  C0000971
# 11681    99    97  000097_1       000097_1            NOTOX_97  C0000971
# 11682    99    97  000097_1       000097_1            NOTOX_97  C0000971
#
#        aeid                            aenm   m0id   m1id   m2id   m3id  logc  \
# ...

# %%
master=pd.read_excel("~/Box/TCPL_Database/Step_1_raw_input_files/Chemicals/MASTER_TCPL_COMPOUND_LIST_20210224.xlsx")
master["ATOM_ID_UCSF"]= master.compound_id.str.rsplit(pat='ATOM', n=1, expand=True)[[1]]
master.columns
# Out:
# Index(['spid', 'chid', 'chnm', 'casn', 'dsstox_substance_id', 'alt_name_1',
#        'alt_name_2', 'alt_name_3', 'CASRN_ID', 'CASRN_alt', 'ATOM_LOT',
#        'ATOM_ID_GSK', 'compound_id', 'names_new', 'pcid_from_name', 'smiles',
#        'smiles_pcid', 'source', 'Morgan', 'SMDC', 'Proprietary', 'MRP3_comb',
#        'APR_toxcast_MMP', 'SMDC_new', 'Chembl_txp_all', 'Hafey',
#        'ATOM_ID_UCSF'],
#       dtype='object')
