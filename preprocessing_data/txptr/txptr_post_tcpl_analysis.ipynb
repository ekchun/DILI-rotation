# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from matplotlib_venn import venn2, venn3, venn2_circles
import seaborn as sns

# This module is used for AMPL data curation
import atomsci.ddm.utils.curate_data as curate_data

# This module is used by AMPL to process chemical structures
import atomsci.ddm.utils.struct_utils as struct_utils

pd.set_option('display.max_columns',(90))
pd.set_option('display.max_rows',(16))

# %%
df=pd.read_csv('~/Box/TCPL_Database/Step_5_tcpl_processed/AKP_Giacomini_Txptr_curve_fit_all.csv')
df
# Out:
#      spid  chid      casn            chnm dsstox_substance_id       code  \
# 0     100    98  000098_1     zatom000371            NOTOX_98   C0000981
# 1     100    98  000098_1     zatom000371            NOTOX_98   C0000981
# 2     103   101   9869676  schembl4463178           NOTOX_101   C9869676
# 3     103   101   9869676  schembl4463178           NOTOX_101   C9869676
# 4     106   104  000104_1     zatom000483           NOTOX_104   C0001041
# ..    ...   ...       ...             ...                 ...        ...
# 185    90    88  000088_1     zatom000433            NOTOX_88   C0000881
# 186    92    90  71236597     gsk-2814338            NOTOX_90  C71236597
# 187    94    92  10252640      gsk-356278      DTXSID40222401  C10252640
# 188    96    94  000094_1     zatom000455            NOTOX_94   C0000941
# 189    96    94  000094_1     zatom000455            NOTOX_94   C0000941
#
#      aeid                             aenm  m5id  m4id       bmad    resp_max  \
# ...

# %%
chems=pd.read_csv("/Users/paulsonak/Box/TCPL_Database/Step_1_raw_input_files/Chemicals/MASTER_TCPL_COMPOUND_LIST.csv")
chems
# Out:
#                spid  chid                     chnm       casn  \
# 0                 1     1               vofopitant    6918331
# 1                19     1               vofopitant    6918331
# 2                 3     3              zafirlukast       5717
# 3               164     3              zafirlukast       5717
# 4                 4     4                sb-281832   70195573
# ...             ...   ...                      ...        ...
# 1902  DTXSID4021393  1895       Triethylene glycol       8172
# 1903  DTXSID1020807  1896  2-Mercaptobenzothiazole     697993
# 1904  DTXSID5020601  1897        Ethylene thiourea    2723650
# 1905  DTXSID8044175  1898           Clove leaf oil  319351646
# 1906  DTXSID8023892  1899                Abamectin  254761708
#
#      dsstox_substance_id                                         alt_name_1  \
# 0                NOTOX_1                                                NaN
# ...
